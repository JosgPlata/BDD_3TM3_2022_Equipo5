# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
DATABASE_CONNECTION="mssql+pyodbc://SA:N0m3l0n0m3l0@localhost/AdventureWorks2019?driver=ODBC+Driver+17+for+SQL+Server"
engine = create_engine(DATABASE_CONNECTION)
connection = engine.connect()

# %%
engineMYSQL = create_engine("mariadb+pymysql://WorkBen:N0m3l0n0m3l0@localhost/Escuela?charset=utf8mb4")
connectionMYSQL = engineMYSQL.connect()
Q2="""select idMateria, Semestre, sum(naprobados) / sum(inscritos) pnaprobados
from vANAProfesorMSG
where semestre = "20212" or semestre = "20221" 
group by idMateria, semestre;"""
data=pd.read_sql_query(Q2,connectionMYSQL)
data
# Out:
#   idmateria semestre  pnaprobados
# 0      T203    20212          1.0
# 1      T302    20221          1.0
# 2      T410    20221          NaN

# %%
data=pd.read_sql_query("select * from AdventureWorks2019.dbo.AWBuildVersion",connection)
data
# Out:
#    SystemInformationID Database Version             VersionDate  \
# 0                    1    14.0.1000.169 2017-08-22 19:39:35.643
#
#              ModifiedDate
# 0 2017-10-27 14:33:02.347

# %%
data=pd.read_sql_query("select * from AdventureWorks2019.HumanResources.Department",connection)
data
# Out:
#     DepartmentID                        Name  \
# 0              1                 Engineering
# 1              2                 Tool Design
# 2              3                       Sales
# 3              4                   Marketing
# 4              5                  Purchasing
# 5              6    Research and Development
# 6              7                  Production
# 7              8          Production Control
# 8              9             Human Resources
# 9             10                     Finance
# 10            11        Information Services
# 11            12            Document Control
# 12            13           Quality Assurance
# 13            14  Facilities and Maintenance
# 14            15      Shipping and Receiving
# 15            16                   Executive
#
#                                GroupName ModifiedDate
# 0               Research and Development   2008-04-30
# 1               Research and Development   2008-04-30
# ...
